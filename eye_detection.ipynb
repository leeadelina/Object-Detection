# %%
import cv2

# %%
# !wget http://dlib.net/files/shape_predictor_68_face_landmarks.dat.bz2
# !bzip2 -d shape_predictor_68_face_landmarks.dat.bz2
# Out:
# --2024-09-30 06:33:14--  http://dlib.net/files/shape_predictor_68_face_landmarks.dat.bz2
# Resolving dlib.net (dlib.net)... 107.180.26.78
# Connecting to dlib.net (dlib.net)|107.180.26.78|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 64040097 (61M)
# Saving to: ‘shape_predictor_68_face_landmarks.dat.bz2’
#
# shape_predictor_68_ 100%[===================>]  61.07M  18.7MB/s    in 3.3s
#
# 2024-09-30 06:33:18 (18.7 MB/s) - ‘shape_predictor_68_face_landmarks.dat.bz2’ saved [64040097/64040097]

# %%
# !wget https://github.com/opencv/opencv/blob/master/data/haarcascades/haarcascade_eye.xml
# Out:
# --2024-09-30 06:36:23--  https://github.com/opencv/opencv/blob/master/data/haarcascades/haarcascade_eye.xml
# Resolving github.com (github.com)... 20.27.177.113
# Connecting to github.com (github.com)|20.27.177.113|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘haarcascade_eye.xml’
#
# haarcascade_eye.xml     [  <=>               ]   1.65M  5.66MB/s    in 0.3s
#
# 2024-09-30 06:36:24 (5.66 MB/s) - ‘haarcascade_eye.xml’ saved [1727832]

# %%
# !wget https://github.com/opencv/opencv/blob/master/data/haarcascades/haarcascade_frontalface_default.xml
# Out:
# --2024-09-30 06:37:13--  https://github.com/opencv/opencv/blob/master/data/haarcascades/haarcascade_frontalface_default.xml
# Resolving github.com (github.com)... 20.27.177.113
# Connecting to github.com (github.com)|20.27.177.113|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘haarcascade_frontalface_default.xml’
#
# haarcascade_frontal     [  <=>               ]   2.73M  9.32MB/s    in 0.3s
#
# 2024-09-30 06:37:14 (9.32 MB/s) - ‘haarcascade_frontalface_default.xml’ saved [2865087]

# %%
from google.colab.patches import cv2_imshow

# %%
a = "/content/394091-1670218124.jpg"
b = "/content/깜빡핑.png"

# %%
img= cv2.imread(a)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=700x466>

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=L size=700x466>

# %%
cv2.data.haarcascades +'haarcascade_frontalface_default.xml'
# Out:
# '/usr/local/lib/python3.10/dist-packages/cv2/data/haarcascade_frontalface_default.xml'

# %%
# read the haarcascade to detect the faces in an image
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades +'haarcascade_frontalface_default.xml')

# read the haarcascade to detect the eyes in an image
eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades +'haarcascade_eye.xml')

# %%
# detects faces in the input image
faces = face_cascade.detectMultiScale(gray,
                                       scaleFactor=1.5,
                                       minNeighbors=3,
                                       minSize=(5, 5))
print('Number of detected faces:', len(faces))
# Out:
# Number of detected faces: 2

# %%
faces
# Out:
# array([[262, 119, 182, 182],
#        [225,  73, 273, 273]], dtype=int32)

# %%
for (x,y,w,h) in faces:
   roi_gray = gray[y:y+h, x:x+w]
   roi_color = img[y:y+h, x:x+w]

   # detects eyes of within the detected face area (roi)
   eyes = eye_cascade.detectMultiScale(roi_gray)

   # draw a rectangle around eyes
   for (ex,ey,ew,eh) in eyes:
      cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,255),2)

# %%
# display the image with detected eyes
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=700x466>

# %%
img= cv2.imread(b)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=408x552>

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=L size=408x552>

# %%
# detects faces in the input image
eyes = eye_cascade.detectMultiScale(img,
                                    # scaleFactor=2,
                                       #minNeighbors=1,
                                       minSize=(50, 50)
)
print('Number of detected faces:', len(eyes))
eyes
# Out:
# Number of detected faces: 2
# array([[270, 225,  71,  71],
#        [131, 261, 101, 101]], dtype=int32)

# %%
for (ex,ey,ew,eh) in eyes:
    cv2.rectangle(img,(ex,ey),(ex+ew,ey+eh),(0,0,255),2)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=408x552>

# %%
ret, thresh = cv2.threshold(gray,0,255,cv2.THRESH_BINARY_INV+cv2.THRESH_OTSU)

# %%
cv2_imshow(thresh)
# Out:
# <PIL.Image.Image image mode=L size=408x552>

# %%
#########################################

# %%
# !unzip -qq "/content/season_1.zip" -d "/content/s1/"

# %%
import glob

# %%
file_list = glob.glob("/content/s1/시즌1/*.png")
file_list
# Out:
# ['/content/s1/시즌1/무거핑.png',
#  '/content/s1/시즌1/차차핑.png',
#  '/content/s1/시즌1/노리핑.png',
#  '/content/s1/시즌1/똑똑핑.png',
#  '/content/s1/시즌1/따라핑.png',
#  '/content/s1/시즌1/플라핑.png',
#  '/content/s1/시즌1/나르핑.png',
#  '/content/s1/시즌1/덜덜핑.png',
#  '/content/s1/시즌1/부끄핑.png',
#  '/content/s1/시즌1/라라핑.png',
#  '/content/s1/시즌1/베베핑.png',
#  '/content/s1/시즌1/키키핑.png',
#  '/content/s1/시즌1/또까핑.png',
#  '/content/s1/시즌1/아잉핑.png',
#  '/content/s1/시즌1/부투핑.png',
#  '/content/s1/시즌1/아휴핑.png',
#  '/content/s1/시즌1/차캐핑.png',
#  '/content/s1/시즌1/떠벌핑.png',
#  '/content/s1/시즌1/찌릿핑.png',
#  '/content/s1/시즌1/앙대핑.png',
#  '/content/s1/시즌1/아자핑.png',
#  '/content/s1/시즌1/차나핑.png',
#  '/content/s1/시즌1/꺼꿀핑.png',
#  '/content/s1/시즌1/하츄핑.png',
#  '/content/s1/시즌1/딱풀핑.png',
#  '/content/s1/시즌1/바네핑.png',
#  '/content/s1/시즌1/씽씽핑.png',
#  '/content/s1/시즌1/해핑.png',
#  '/content/s1/시즌1/무셔핑.png',
#  '/content/s1/시즌1/투투핑.png',
#  '/content/s1/시즌1/다조핑.png',
#  '/content/s1/시즌1/토이핑.png',
#  '/content/s1/시즌1/코자핑.png',
# ...

# %%
results = []
for f in file_list:
    img= cv2.imread(f)
    #cv2_imshow(img)
    eyes = eye_cascade.detectMultiScale(img,
                                    # scaleFactor=2,
                                       #minNeighbors=1,
                                       minSize=(50, 50))
    print(f, ' : Number of detected faces:', len(eyes))
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(img,(ex,ey),(ex+ew,ey+eh),(0,0,255),2)
    cv2_imshow(img)
    results.append([f,eyes])
